# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import geopandas as gpd
import contextily as cx
import os
import seaborn as sns
import shapely as shp

# %%
for csv_file in os.listdir("./data_clean"):
    if csv_file[-3:] == "csv":
        globals()[csv_file[:-4]] = pd.read_csv("./data_clean/" + csv_file)

# %% [markdown]
# # Analyse de la stratégie de routage
# ## Analyse du remplissage des camions

# %%
routes["fill_rate"] = routes["fill_volume"] / trucks["truck_volume"].iloc[0]

# %%
matplotlib.colors.Colormap("Pastel1")

# %%
plt.figure(figsize=(15,8))
sns.histplot(x="fill_rate", hue="from_warehouse", data=routes, stat="probability", multiple="dodge", common_norm=False, bins=5, palette=sns.color_palette("muted")[:5])
plt.title("Distribution des taux de remplissage des camions")
# Out:
# Text(0.5, 1.0, 'Distribution des taux de remplissage des camions')

# %%
routes["n_route"] = 1
print(f"{len(routes[routes['fill_rate']<0.8])/len(routes) * 100:.0f}% des trajets voient leur camion rempli à moins de 80% !")
print(f"{len(routes[routes['fill_rate']<0.5])/len(routes) * 100:.0f}% des trajets voient leur camion rempli à moins de 50% !")
# Out:
# 47% des trajets voient leur camion rempli à moins de 80% !
# 14% des trajets voient leur camion rempli à moins de 50% !

# %%
routes["route_date"] = pd.to_datetime(routes["route_date"])
df = routes[["route_date", "fill_rate", "from_warehouse"]].groupby(["route_date", "from_warehouse"]).agg("mean").reset_index()

# %%
df
# Out:
#     route_date    from_warehouse  fill_rate
# 0   2021-01-02             Cergy   0.096412
# 1   2021-01-02  Clermont-Ferrand   0.073697
# 2   2021-01-02             Reims   0.023266
# 3   2021-01-03           Avignon   0.043332
# 4   2021-01-03             Cergy   0.116737
# ..         ...               ...        ...
# 888 2021-06-29           Avignon   0.728766
# 889 2021-06-29             Cergy   0.766974
# 890 2021-06-29  Clermont-Ferrand   0.778304
# 891 2021-06-29         Montauban   0.779547
# 892 2021-06-29             Reims   0.662897
#
# [893 rows x 3 columns]

# %%
dff = df.rolling(10, on="route_date").mean().join(df[["from_warehouse"]])

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x="route_date", y="fill_rate", hue="from_warehouse", data=df, linewidth=2)
plt.title("Évolution des taux de remplissage moyens des camions par entrepôts")
plt.show()

# %% [markdown]
# On constate de nombreux pics, sans doute liés à la contrainte des 24h qui limitent les possibilités de lissage sur plusieurs jours.

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x="route_date", y="fill_rate", hue="from_warehouse", data=dff, linewidth=2)
plt.title("Évolution des taux de remplissage moyens des camions par entrepôts (moyenne glissante sur 10 jours)")
plt.show()

# %% [markdown]
# ## Analyse du trajet des camions

# %%
routes
# Out:
#       Unnamed: 0                truck_id   duration  fill_volume  n_units  \
# 0              0  jehwGBpNg2rDLeKoYeiaLs   2.167136       5.9879     87.0
# 1              1  XnzFnkALW3tLnzrdCVFyKH  23.230412       4.7060    190.0
# 2              2  dwQ5Xd6TwcXURBczFdRXVy   6.995822      10.9609    148.0
# 3              3  A58tMgZVPfe2ucEBcCSXTW   4.785198       1.8904     79.0
# 4              4  KRNfDAmUV8bRzkxhdAYfkj   4.413343       0.4536     63.0
# ...          ...                     ...        ...          ...      ...
# 7421        7421  4q43tx2jAeJtMFz4UwGZpD   1.150110      68.8800     41.0
# 7422        7422  kRYyBXN9TeJF8Mewj55RdU   8.596979      69.6117     95.0
# 7423        7423  9LBChivrfyZZrBMpcjLtGv  21.367729      49.4855    307.0
# 7424        7424  YjL2avoUgG3tdDxditdH5V   1.651791      79.3388     41.0
# 7425        7425  kxqnMiQUSGZaetom73TmYt   1.864936      57.9040     40.0
#
#                                                  orders    from_warehouse  \
# 0       nK4iPf8nrGA9yivRH66ehS > jnsH9ndQ3UKcWSbb2UMkFn  Clermont-Ferrand
# 1     XHfAWaLxTFbo5UQwtd7CMz > Wd6rPc4wPRNmt3ruf3F7o...             Cergy
# 2     gQi59MNfDa5YFpVWxfmPin > FaqH6N2zWCeykLh5f9VPW...             Cergy
# 3       7bzBdqUKWXyNrAhntXNrBq > BZsYUHDe4eVj7HaeM8MBt7             Reims
# 4       DfN8XqUVeVHjTW3Pat76Tr > MUT2TaTikTsi8FzSCnimxv  Clermont-Ferrand
# ...                                                 ...               ...
# 7421                             JXpxeURRDzSAgeE5FiPh7H         Montauban
# 7422  EpgfunMiFtk37q3hniS8Te > Cujg8Rgb8uvYWtSzA4y4a...         Montauban
# 7423  bRay4XPtfJtqcfu9PcfHUN > Tn3ehPUBELhd3JxMPSD6f...         Montauban
# 7424    S254SKuGaFfScnCCyAUfWk > 9pvVqJzgLFF2PcypNjAc5V         Montauban
# 7425                             CeyiacsHjGHu3ZS6UvoHqj         Montauban
#
#      route_date                                              stops  \
# 0    2021-01-02                         Clermont-Ferrand > Bourges
# 1    2021-01-02  Cergy > Saint-Nazaire > Saint-Denis > Rouen > ...
# 2    2021-01-02  Cergy > Boulogne-Billancourt > Aubervilliers >...
# 3    2021-01-02                            Reims > Épinal > Troyes
# 4    2021-01-03                    Clermont-Ferrand > Villeurbanne
# ...         ...                                                ...
# 7421 2021-06-29                                 Montauban > Pessac
# 7422 2021-06-29               Montauban > Pessac > Perpignan > Pau
# 7423 2021-06-29  Montauban > Niort > Mérignac > Montauban > Lim...
# 7424 2021-06-29                            Montauban > La Rochelle
# 7425 2021-06-29                               Montauban > Bordeaux
#
#       total_distance  fill_rate  n_route
# 0         153.950611   0.073697        1
# 1        1416.184102   0.057920        1
# 2         184.704129   0.134903        1
# 3         390.851862   0.023266        1
# 4         139.447356   0.005583        1
# ...              ...        ...      ...
# 7421      180.534974   0.847754        1
# 7422      821.990387   0.856759        1
# 7423     1034.651961   0.609052        1
# 7424      308.878633   0.976478        1
# 7425      178.823800   0.712665        1
#
# [7426 rows x 12 columns]

# %%
def create_path(stops):
    stops = stops.split(" > ")
    coordinates = []
    for stop in stops:
        city = cities[cities["city"] == stop].iloc[0]
        coordinates.append([city["lng"], city["lat"]])
    if len(coordinates) == 1:
        coordinates = 2*coordinates
    return shp.geometry.LineString(coordinates)

# %%
routes["path"] = routes["stops"].apply(create_path)

# %%
fig, ax = plt.subplots(figsize=(15, 15))

gdf_cities = gpd.GeoDataFrame(cities, geometry=gpd.points_from_xy(cities.lng, cities.lat), crs=4326)
gdf_cities.to_crs(epsg=3857).plot(ax=ax, column="is_warehouse", markersize=200)

gdf = gpd.GeoDataFrame(routes, geometry=routes.path, crs=4326)
gdf.to_crs(epsg=3857).plot(ax=ax, column="from_warehouse")

cx.add_basemap(ax, source=cx.providers.CartoDB.Voyager, zoom=6)
ax.axis('off')
ax.set_title("Localisation des villes")
plt.show()

# %%
routes = routes.drop(["path", "geometry"], axis=1)

# %%
df = routes[["route_date", "total_distance", "from_warehouse"]].groupby(["route_date", "from_warehouse"]).agg("sum").reset_index()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x="route_date", y="total_distance", hue="from_warehouse", data=df, linewidth=2)
plt.title("Évolution de la distance totale parcourue par entrepôt")
plt.show()
